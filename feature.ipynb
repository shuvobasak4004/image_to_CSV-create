# %%
# !pip install pandas tensorflow pillow
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\aic\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\aic\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\aic\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\aic\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\aic\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\aic\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\aic\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\aic\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
import pandas as pd
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

# Function to extract features from an image
def extract_features(image_path):
    # Load and preprocess the image
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Get features from the model
    features = model.predict(img_array)
    return features

# Input image file path
input_image_path = 'F:/Machine_Learning/new/a.jpg'

# Extract features from the input image
image_features = extract_features(input_image_path)

# Create a DataFrame from the features
df = pd.DataFrame(image_features, columns=[f'feature_{i}' for i in range(image_features.shape[1])])

# Save the features to a CSV file
df.to_csv('F:/Machine_Learning/new/image_features.csv', index=False)

# Display the DataFrame with image features
df.head()
# Out:
# 1/1 [==============================] - 1s 970ms/step
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   4.228666   1.027574   1.236052        0.0   0.144033   0.016819
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_2038  \
# 0        0.0        0.0   0.111295   0.182175  ...      0.067348
#
#    feature_2039  feature_2040  feature_2041  feature_2042  feature_2043  \
# 0           0.0      0.657286           0.0           0.0       0.45173
#
#    feature_2044  feature_2045  feature_2046  feature_2047
# 0           0.0       0.47977      0.898613      0.221566
#
# [1 rows x 2048 columns]

# %%
import pandas as pd
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

# Function to extract features from an image
def extract_features(image_path):
    # Load and preprocess the image
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Get features from the model
    features = model.predict(img_array)
    return features

# Input image file path
input_image_path = 'F:/Machine_Learning/new/a.jpg'

# Extract features from the input image
image_features = extract_features(input_image_path)

# Create a DataFrame from the features
df = pd.DataFrame(image_features, columns=[f'feature_{i}' for i in range(image_features.shape[1])])

# Save the features to a CSV file with column names
df.to_csv('F:/Machine_Learning/new/image_features.csv', index=False)

# Display the DataFrame with image features
df.head()
# Out:
# 1/1 [==============================] - 1s 811ms/step
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   4.228666   1.027574   1.236052        0.0   0.144033   0.016819
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_2038  \
# 0        0.0        0.0   0.111295   0.182175  ...      0.067348
#
#    feature_2039  feature_2040  feature_2041  feature_2042  feature_2043  \
# 0           0.0      0.657286           0.0           0.0       0.45173
#
#    feature_2044  feature_2045  feature_2046  feature_2047
# 0           0.0       0.47977      0.898613      0.221566
#
# [1 rows x 2048 columns]

# %% [markdown]
# # main

# %%
import os
import pandas as pd
import numpy as np
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image

# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

# Directory where your training data is stored
train_dir = 'F:/Machine_Learning/new/train'

# Function to extract features from an image
def extract_features(image_path):
    # Load and preprocess the image
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Get features from the model
    features = model.predict(img_array)
    return features.flatten()  # Flatten the feature vector

# Create empty lists to store features and labels
features_list = []
labels_list = []

# Iterate through subdirectories (each representing a class)
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)

    # Iterate through images in the class directory
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        
        # Extract features for the image
        image_features = extract_features(image_path)
        
        # Append features and class label to lists
        features_list.append(image_features)
        labels_list.append(class_name)

# Create a DataFrame from the features and labels
features_df = pd.DataFrame(features_list)
features_df['label'] = labels_list

# Save the features and labels to a CSV file
features_df.to_csv('F:/Machine_Learning/new/train_image_features.csv', index=False)

# Display the DataFrame with image features and labels
print(features_df.head())
# Out:
# ...
# 1/1 [==============================] - 0s 97ms/step
#           0         1         2         3         4         5         6  \
# 0  3.702364  0.141979  0.686187  0.059849  0.046230  0.020937  0.148590
# 1  4.851595  0.223419  1.190646  0.000000  0.177926  0.000000  0.021463
# 2  4.595733  0.600339  0.362119  0.006345  0.036736  0.000000  0.000000
# 3  2.073169  0.349045  0.047997  0.126432  0.106730  0.000000  0.000000
# 4  2.861204  1.071189  0.907868  0.051074  0.141110  0.000286  0.005930
#
#           7         8         9  ...      2039      2040  2041      2042  \
# 0  0.048095  0.000000  0.184705  ...  0.000000  0.062503   0.0  0.000000
# 1  0.000000  0.000000  0.034326  ...  0.029666  0.085073   0.0  0.000000
# 2  0.000000  0.170454  0.232557  ...  0.006755  0.010354   0.0  0.052007
# 3  0.025479  0.000000  0.000000  ...  0.188079  0.000000   0.0  0.000000
# 4  0.000000  0.000000  0.311573  ...  0.000000  0.027009   0.0  0.008606
#
# ...
